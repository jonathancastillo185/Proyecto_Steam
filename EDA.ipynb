# %%
import pandas as pd
import matplotlib as nlp
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
import scipy.stats as estadísticas

# %%
df = pd.read_csv(r'data_set_limpio\games_dummies.csv.gz')
item = pd.read_csv(r'data_set_limpio/items_preparado.csv.gz')
opinion = pd.read_csv(r'data_set_limpio/reviews_preparado.csv.gz')
opinionfiltrado = pd.read_csv(r'data_set_limpio/reviews_preparado.csv.gz')
games_dummies = pd.read_csv(r'data_set_limpio/games_dummies.csv.gz')
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_22656\3841251468.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'data_set_limpio\games_dummies.csv.gz')
# C:\Users\jonat\AppData\Local\Temp\ipykernel_22656\3841251468.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_dummies = pd.read_csv(r'data_set_limpio/games_dummies.csv.gz')

# %%
df_filtered = df[(df['release_date'] >= 2000) & (df['release_date'] <= 2019)]

# %%
df_filtered['release_date'].unique()
# Out:
# array([2018, 2017, 2016, 2006, 2005, 2003, 2007, 2002, 2000, 2001, 2004,
#        2008, 2009, 2010, 2011, 2013, 2012, 2014, 2015, 2019], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ajusta el tamaño de la figura según tu preferencia
plt.figure(figsize=(10, 6))

# Crea un gráfico de barras para visualizar el rango de precios por año
sns.barplot(data=df, y='release_date', x='price')
plt.xlabel('Año')
plt.ylabel('Rango de Precios')
plt.title('Rango de Precios por Año')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df['price'] = pd.to_numeric(df['price'], errors='coerce')
# Agregar precios por año utilizando la media
aggregated_prices = df.groupby('release_date')['price'].mean().reset_index()

# Ajusta el tamaño de la figura según tu preferencia
plt.figure(figsize=(10, 6))

# Crea un boxplot para visualizar la distribución de precios por cada año
sns.boxplot(data=df, y='release_date', x='price')
plt.xlabel('Año')
plt.ylabel('Precios')
plt.title('Distribución de Precios por Año')

plt.show()
